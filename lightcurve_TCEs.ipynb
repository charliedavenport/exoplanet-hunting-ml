# %%
import polars as pl
from polars import col
from lightkurve import search_lightcurve
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
kepler_planets = pl.scan_csv("kepler-data/kepler-planets.csv")
kepler_planets.collect()
# Out:
# shape: (2_770, 92)
# ┌────────────┬───────────┬───────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ pl_name    ┆ hostname  ┆ default_f ┆ sy_snum ┆ … ┆ sy_gaiama ┆ rowupdate ┆ pl_pubdat ┆ releaseda │
# │ ---        ┆ ---       ┆ lag       ┆ ---     ┆   ┆ gerr2     ┆ ---       ┆ e         ┆ te        │
# │ str        ┆ str       ┆ ---       ┆ i64     ┆   ┆ ---       ┆ str       ┆ ---       ┆ ---       │
# │            ┆           ┆ i64       ┆         ┆   ┆ f64       ┆           ┆ str       ┆ str       │
# ╞════════════╪═══════════╪═══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ KIC        ┆ KIC       ┆ 1         ┆ 1       ┆ … ┆ -0.000404 ┆ 2015-12-2 ┆ 2015-12   ┆ 2016-01-0 │
# │ 10525077 b ┆ 10525077  ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 5         │
# │ KIC        ┆ KIC       ┆ 1         ┆ 1       ┆ … ┆ -0.000258 ┆ 2015-12-2 ┆ 2015-12   ┆ 2016-01-0 │
# │ 3558849 b  ┆ 3558849   ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 5         │
# │ KIC        ┆ KIC       ┆ 1         ┆ 1       ┆ … ┆ -0.00029  ┆ 2015-12-2 ┆ 2015-12   ┆ 2016-01-0 │
# │ 5437945 b  ┆ 5437945   ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 5         │
# │ KIC        ┆ KOI-7892  ┆ 1         ┆ 1       ┆ … ┆ -0.000257 ┆ 2015-12-2 ┆ 2015-12   ┆ 2016-01-0 │
# │ 8540376 b  ┆           ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 5         │
# │ KIC        ┆ KOI-7892  ┆ 1         ┆ 1       ┆ … ┆ -0.000257 ┆ 2015-12-2 ┆ 2015-12   ┆ 2016-01-0 │
# │ 8540376 c  ┆           ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 5         │
# │ …          ┆ …         ┆ …         ┆ …       ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Kepler-997 ┆ Kepler-99 ┆ 1         ┆ 1       ┆ … ┆ -0.0002   ┆ 2016-05-0 ┆ 2016-05   ┆ 2016-05-1 │
# │ b          ┆ 7         ┆           ┆         ┆   ┆           ┆ 6         ┆           ┆ 0         │
# │ Kepler-998 ┆ Kepler-99 ┆ 1         ┆ 1       ┆ … ┆ -0.000233 ┆ 2016-05-0 ┆ 2016-05   ┆ 2016-05-1 │
# │ b          ┆ 8         ┆           ┆         ┆   ┆           ┆ 6         ┆           ┆ 0         │
# │ Kepler-999 ┆ Kepler-99 ┆ 1         ┆ 1       ┆ … ┆ -0.000185 ┆ 2016-05-0 ┆ 2016-05   ┆ 2016-05-1 │
# │ b          ┆ 9         ┆           ┆         ┆   ┆           ┆ 6         ┆           ┆ 0         │
# │ PH1 b      ┆ PH1       ┆ 1         ┆ 4       ┆ … ┆ -0.001604 ┆ 2014-05-1 ┆ 2013-05   ┆ 2014-05-1 │
# │            ┆           ┆           ┆         ┆   ┆           ┆ 4         ┆           ┆ 4         │
# │ PH2 b      ┆ PH2       ┆ 1         ┆ 1       ┆ … ┆ -0.000185 ┆ 2024-09-1 ┆ 2024-03   ┆ 2024-09-1 │
# │            ┆           ┆           ┆         ┆   ┆           ┆ 3         ┆           ┆ 3         │
# └────────────┴───────────┴───────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
┆ f64       ┆ f64       ┆ f64       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2304168  ┆ 2         ┆ 0         ┆ 431.719   ┆ … ┆ 3.67      ┆ 0.49      ┆ 3.332     ┆ 1.718     │
# │ 2304235  ┆ 1         ┆ 0         ┆ 0.570607  ┆ … ┆ 2.12      ┆ 0.56      ┆ 26.32     ┆ 17.39     │
# │ 2304566  ┆ 1         ┆ 0         ┆ 0.68948   ┆ … ┆ 3.29      ┆ 0.43      ┆ 5.894     ┆ 2.825     │
# │ 2304320  ┆ 1         ┆ 0         ┆ 16.5408   ┆ … ┆ 4.57      ┆ 0.05      ┆ 0.769     ┆ 0.049     │
# │ 2303365  ┆ 2         ┆ 0         ┆ 0.520697  ┆ … ┆ 3.64      ┆ 0.46      ┆ 3.603     ┆ 1.762     │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 11912947 ┆ 6         ┆ 0         ┆ 522.609   ┆ … ┆ 4.93      ┆ 0.04      ┆ 0.321     ┆ 0.033     │
# │ 11922283 ┆ 3         ┆ 1         ┆ 256.782   ┆ … ┆ 2.89      ┆ 0.3       ┆ 11.11     ┆ 4.219     │
# │ 11922283 ┆ 4         ┆ 0         ┆ 0.878715  ┆ … ┆ 2.89      ┆ 0.3       ┆ 11.11     ┆ 4.219     │
# │ 11922290 ┆ 1         ┆ 0         ┆ 114.662   ┆ … ┆ 4.56      ┆ 0.09      ┆ 0.712     ┆ 0.082     │
# │ 11922648 ┆ 1         ┆ 0         ┆ 1.75641   ┆ … ┆ 4.57      ┆ 0.18      ┆ 0.812     ┆ 0.222     │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
(tces
    .filter((col("kepid") == 10666592) & (col("tce_plnt_num") == 1))
    .collect()
)
# Out:
# shape: (1, 26)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ kepid    ┆ tce_plnt_ ┆ tce_rogue ┆ tce_perio ┆ … ┆ tce_slogg ┆ tce_slogg ┆ tce_sradi ┆ tce_sradi │
# │ ---      ┆ num       ┆ _flag     ┆ d         ┆   ┆ ---       ┆ _err      ┆ us        ┆ us_err    │
# │ i64      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ i64       ┆ i64       ┆ f64       ┆   ┆           ┆ f64       ┆ f64       ┆ f64       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10666592 ┆ 1         ┆ 0         ┆ 2.20473   ┆ … ┆ 4.02      ┆ 0.03      ┆ 1.952     ┆ 0.11      │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
lc = search_lightcurve("KIC10666592")
lc[:5]
# Out:
# SearchResult containing 5 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 03 2009 Kepler      60 kplr010666592      0.0
#   1 Kepler Quarter 00 2009 Kepler      60 kplr010666592      0.0
#   2 Kepler Quarter 03 2009 Kepler      60 kplr010666592      0.0
#   3 Kepler Quarter 01 2009 Kepler      60 kplr010666592      0.0
#   4 Kepler Quarter 02 2009 Kepler      60 kplr010666592      0.0

# %%
lc = search_lightcurve('Kepler-2 b', exptime=60, author='Kepler').download_all().stitch()
lc.scatter(s=1.0)
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized Flux'>

# %%
tce = tces.filter((col("kepid") == 10666592) & (col("tce_plnt_num") == 1))


transit_epoch = tce.select("tce_time0bk").collect().item()
period = tce.select("tce_period").collect().item()
transit_events = [transit_epoch + (period * i) for i in range(10000)]

# %%
flat_lc = lc.remove_outliers(sigma_lower=float("inf"), sigma_upper=5).flatten()

# %%
ax = plt.subplot()
flat_lc.scatter(ax=ax, fc="black", s=1.0)
x_min, x_max = 1003, 1003.5
ax.set_xlim(x_min, x_max)
for transit_event_time in transit_events:
    if (transit_event_time <= x_max) & (transit_event_time >= x_min):
        ax.axvline(transit_event_time, color='red', linestyle='--', linewidth=0.5, alpha=0.75)
    if transit_event_time > x_max:
        break

# %%
def plot_kepler_lc_transit(kep_id: int, tce_planet_number: int, x_min: float, x_max: float, exp_time=60):
    
    print(f"Searching for light curve for KIC {kep_id}...")
    lc = search_lightcurve(f"KIC{kep_id}", exptime=exp_time, author="Kepler")
    
    print("Downloading light curve...")
    lc = lc.download_all().stitch()
    
    print("Processing light curve...")
    flat_lc = lc.remove_outliers(sigma_lower=5, sigma_upper=5) #.flatten()
    
    print("Getting TCE data...")
    tce = tces.filter((col("kepid") == kep_id) & (col("tce_plnt_num") == tce_planet_number))
    transit_epoch = tce.select("tce_time0bk").collect().item()
    period = tce.select("tce_period").collect().item()
    transit_events = [transit_epoch + (period * i) for i in range(-500,500)]
    
    print("Generating plot...")
    ax = plt.subplot()
    flat_lc.scatter(ax=ax, fc="black", s=1.0)
    ax.set_xlim(x_min, x_max)
    for transit_event_time in transit_events:
        if (transit_event_time <= x_max) & (transit_event_time >= x_min):
            ax.axvline(transit_event_time, color='red', linestyle='--', linewidth=0.5, alpha=0.75)
        if transit_event_time > x_max:
            break

# %%
# Kepler-2b aka HAT-P-7b
plot_kepler_lc_transit(kep_id=10666592, tce_planet_number=1, x_min=130, x_max=135)
# Out:
# Searching for light curve for Kep ID 10666592...
# Downloading light curve...
# Processing light curve...
# Getting TCE data...
# Generating plot...

# %%
#          kepler-3, kepler-4, kepler-5, kepler-6
kep_ids = [10748390, 11853905, 8191672,  10874614]
(tces
    .filter((col("kepid").is_in(kep_ids)))
    .collect()
)
# Out:
# shape: (5, 26)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ kepid    ┆ tce_plnt_ ┆ tce_rogue ┆ tce_perio ┆ … ┆ tce_slogg ┆ tce_slogg ┆ tce_sradi ┆ tce_sradi │
# │ ---      ┆ num       ┆ _flag     ┆ d         ┆   ┆ ---       ┆ _err      ┆ us        ┆ us_err    │
# │ i64      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆ i64       ┆ i64       ┆ f64       ┆   ┆           ┆ f64       ┆ f64       ┆ f64       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 8191672  ┆ 1         ┆ 0         ┆ 3.54846   ┆ … ┆ 4.07      ┆ 0.05      ┆ 1.746     ┆ 0.154     │
# │ 10874614 ┆ 1         ┆ 0         ┆ 3.2347    ┆ … ┆ 4.24      ┆ 0.06      ┆ 1.291     ┆ 0.095     │
# │ 10874614 ┆ 2         ┆ 0         ┆ 412.028   ┆ … ┆ 4.24      ┆ 0.06      ┆ 1.291     ┆ 0.095     │
# │ 10748390 ┆ 1         ┆ 0         ┆ 4.8878    ┆ … ┆ 4.59      ┆ 0.04      ┆ 0.763     ┆ 0.028     │
# │ 11853905 ┆ 1         ┆ 0         ┆ 3.21366   ┆ … ┆ 4.1       ┆ 0.03      ┆ 1.545     ┆ 0.097     │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# Kepler-3b aka HAT-P-11b
plot_kepler_lc_transit(kep_id=10748390, tce_planet_number=1, x_min=134, x_max=135)
# Out:
# Warning: 10748390 may refer to a different Kepler or TESS target. Please add the prefix 'KIC' or 'TIC' to disambiguate.
# Searching for light curve for KIC 10748390...
# Downloading light curve...
# Processing light curve...
# Getting TCE data...
# Generating plot...

# %%
# Kepler-4b
plot_kepler_lc_transit(11853905, 1, 200, 210)
# Out:
# Warning: 11853905 may refer to a different Kepler or TESS target. Please add the prefix 'KIC' or 'TIC' to disambiguate.
# Searching for light curve for KIC 11853905...
# Downloading light curve...
# Processing light curve...
# Getting TCE data...
# Generating plot...

# %%
plot_kepler_lc_transit(8191672, 1, 200, 205)
# Out:
# Searching for light curve for KIC 8191672...
# Downloading light curve...
# Processing light curve...
# Getting TCE data...
# Generating plot...

# %%
plot_kepler_lc_transit(10874614, 1, 200, 220)
# Out:
# Searching for light curve for KIC 10874614...
# Downloading light curve...
# Processing light curve...
# Getting TCE data...
# Generating plot...
